# %% [markdown]
# # Вывод производной $\frac{1}{x}$ через геометрию
#
# ## 🎯 Главная идея:
#
# Для гиперболы $y = \frac{1}{x}$ выполняется свойство:
#
# $$x \cdot y = 1 \quad \text{(площадь прямоугольника всегда = 1)}$$
#
# При изменении $x$ площадь должна остаться равной 1. Используем это для вывода производной!

# %% [markdown]
# ---
#
# ## Шаг 1: Что происходит при изменении $x$?
#
# Есть прямоугольник со сторонами $x$ и $y = \frac{1}{x}$:
#
# $$\text{Площадь} = x \cdot y = x \cdot \frac{1}{x} = 1$$
#
# При приращении $x \to x + dx$:
# - $x$ увеличивается на $dx$
# - $y$ уменьшается на $dy$ (где $dy < 0$, потому что функция убывает)

# %% [markdown]
# ---
#
# ## Шаг 2: Два маленьких прямоугольника
#
# ### 🟢 Добавленная полоска (справа):
# - **Ширина:** $dx$
# - **Высота:** $y = \frac{1}{x}$ (приблизительно старое значение)
# - **Площадь:** $dx \cdot y = dx \cdot \frac{1}{x} = \frac{dx}{x}$
#
# ### 🟠 Убранная полоска (сверху):
# - **Ширина:** $x$
# - **Высота:** $|dy|$ (модуль, т.к. $dy < 0$)
# - **Площадь:** $x \cdot |dy|$
#
# ---
#
# ### ⚖️ Ключевое свойство:
#
# **Чтобы общая площадь осталась = 1, эти площади должны быть равны:**
#
# $$\boxed{x \cdot |dy| = dx \cdot y}$$

# %% [markdown]
# ---
#
# ## Шаг 3: Выводим производную
#
# Из равенства площадей:
#
# $$x \cdot |dy| = dx \cdot y$$
#
# Подставим $y = \frac{1}{x}$:
#
# $$x \cdot |dy| = dx \cdot \frac{1}{x}$$
#
# Упростим правую часть:
#
# $$x \cdot |dy| = \frac{dx}{x}$$
#
# Разделим обе части на $x$:
#
# $$|dy| = \frac{dx}{x^2}$$
#
# ---
#
# ### ⚠️ Знак минус!
#
# Функция $y = \frac{1}{x}$ **убывает**, поэтому $dy < 0$.
#
# Значит: $|dy| = -dy$
#
# Подставляем:
#
# $$-dy = \frac{dx}{x^2}$$
#
# $$dy = -\frac{dx}{x^2}$$
#
# ---
#
# ### ✅ Производная:
#
# $$\frac{dy}{dx} = -\frac{1}{x^2}$$
#
# $$\boxed{\frac{d}{dx}\left(\frac{1}{x}\right) = -\frac{1}{x^2}}$$

# %% [markdown]
# ---
#
# ## Альтернативный вывод (через дифференциал произведения)
#
# Раз $x \cdot y = 1$ всегда, то при малых изменениях:
#
# $$(x + dx)(y + dy) = 1$$
#
# Раскрываем:
#
# $$xy + x \cdot dy + y \cdot dx + dx \cdot dy = 1$$
#
# Но $xy = 1$, поэтому:
#
# $$x \cdot dy + y \cdot dx + dx \cdot dy = 0$$
#
# При малых $dx$ член $dx \cdot dy$ пренебрежимо мал:
#
# $$x \cdot dy + y \cdot dx \approx 0$$
#
# $$x \cdot dy = -y \cdot dx$$
#
# Разделим на $x \cdot dx$:
#
# $$\frac{dy}{dx} = -\frac{y}{x}$$
#
# Подставим $y = \frac{1}{x}$:
#
# $$\frac{dy}{dx} = -\frac{1/x}{x} = -\frac{1}{x^2}$$
#
# $$\boxed{\frac{d}{dx}\left(\frac{1}{x}\right) = -\frac{1}{x^2}}$$

# %% [markdown]
# ---
#
# ## 📋 Резюме
#
# ### Геометрический смысл:
#
# Для гиперболы $y = \frac{1}{x}$ площадь прямоугольника $x \cdot y = 1$ постоянна.
#
# При изменении $x$ на $dx$:
# - **Добавляется** полоска справа: площадь $= dx \cdot y$
# - **Убирается** полоска сверху: площадь $= x \cdot |dy|$
#
# **Эти площади равны:**
# $$x \cdot |dy| = y \cdot dx$$
#
# ### Вывод производной:
#
# Из равенства площадей:
# $$x \cdot |dy| = \frac{1}{x} \cdot dx$$
#
# $$|dy| = \frac{dx}{x^2}$$
#
# Так как $dy < 0$ (функция убывает):
# $$dy = -\frac{dx}{x^2}$$
#
# **Производная:**
# $$\boxed{\frac{dy}{dx} = -\frac{1}{x^2}}$$
#
# ---
#
# ### 🎯 Ключевая идея:
#
# **Минус появляется потому, что функция убывает!**
#
# Площадь добавленного прямоугольника компенсирует площадь убранного, сохраняя общую площадь = 1. Это и есть геометрический смысл производной для гиперболы!
