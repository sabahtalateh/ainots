# %% [markdown]
# # Курс "Mатематический анализ. Часть 1"
#
# Если вы читаете эти строки, значит вы успешно установили и запустили Jupyter Notebook.
#
# ##  Особенности работы в Jupyter Notebook
#
# 1. Код пишется в "клетках" ```In []:```, результат исполнения - в "клетках" ```Out []:```.
# 2. Stack Trace тоже отображается в клетках ```Out []:```.
# 2. Цифра в квадратных скобках - порядковый номер исполнения данного фрагмента кода.
# 2. Запуск кода: ```Shift - Enter``` - с переходом в следующую "клетку", ```Ctrl - Enter``` - без оного.
# 3. Все переменные, объявленные в "клетке" становятся видимыми внутри всей тетрадки.
# 4. Все переменные, объявленные в тетрадке, видимы только внутри нее и не влияют на другие открытые тетрадки.
#
# ### Если "Что-то пошло не так..."
#
# 1. ```Ctrl - C``` прервет выполнение кода исключением ```KeyboardInterrupt```
# 1. Если это не помогает - надо перезапустить ядро (меню Kernel / Restart), и потом последовательно выполнить все предыдущие "клетки".
# 2. Если и это не помогает - снимите процесс python.
#
#
# ### Синтаксис Python в Jupyter Notebook
#
# 1. Есть подсветка синтаксиса.
# 2. Отступы проставляются автоматически, можно использовать tab.
# 3. По нажатию tab - автозаполнение.
# 4. Символ "?", указанный до или после переменной, открывает окно с информацией о ней (будь это просто переменная или функция).
# 5. Закомментировать строку можно сочетанием клавиш ```Ctrl - /```.

# %%
b = [1, 2, 3, 4, 5]

# %%
s = 'Hello!!'
s
# Out:
# 'Hello!!'

# %%
print(s); b
# Out:
# Hello!!
# [1, 2, 3, 4, 5]

# %%
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
b?
# Out:
# Type:        list
# String form: [1, 2, 3, 4, 5]
# Length:      5
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
# Использую хинтинг(hinting). С версию 3.9 
def mul_numbers(a: float | int, b: float | int) -> float:
    """  Функция умножает два числа """
    return a * b

# %%
mul_numbers(34, 3.1)
# Out:
# 105.4

# %%
# mul_numbers('1', '1')  # TypeError

# %%
mul_numbers?
# Out:
# Signature: mul_numbers(a: float | int, b: float | int) -> float
# Docstring: Функция умножает два числа
# File:      /var/folders/zk/wc07fm1d6sx_8362cmm1sh1xybjh0x/T/ipykernel_82858/2769045436.py
# Type:      function

# %%
# два знака вопроса откроют окно с исходным кодом
mul_numbers??
# Out:
# Signature: mul_numbers(a: float | int, b: float | int) -> float
# Source:
# def mul_numbers(a: float | int, b: float | int) -> float:
#     """  Функция умножает два числа """
#     return a * b
# File:      /var/folders/zk/wc07fm1d6sx_8362cmm1sh1xybjh0x/T/ipykernel_82858/2769045436.py
# Type:      function

# %%
import random as rnd

# %%
rnd.randint??
# Out:
# Signature: rnd.randint(a, b)
# Docstring:
# Return random integer in range [a, b], including both end points.
#
# Source:
#     def randint(self, a, b):
#         """Return random integer in range [a, b], including both end points.
#         """
#         a = _index(a)
#         b = _index(b)
#         if b < a:
#             raise ValueError(f"empty range in randint({a}, {b})")
#         return a + self._randbelow(b - a + 1)
# File:      /opt/anaconda3/envs/matan2/lib/python3.14/random.py
# Type:      method

# %%
import math
math.sin??
# Out:
# Signature: math.sin(x, /)
# Docstring: Return the sine of x (measured in radians).
# Type:      builtin_function_or_method

# %% [markdown]
# ### Список магических команд

# %%
lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# Пример `latex`:

# %% [markdown]
# $$
# f_i = \frac{3}{4}
# $$

# %%
print("C:\\name")
# Out:
# C:\name

# %%
# %pwd
# Out:
# '/Users/kravtsov777/Code/ainots/specmatan/matan1'

# %%
# %cd /Users/kravtsov777/Code/ainots/specmatan
# Out:
# /Users/kravtsov777/Code/ainots/specmatan

# %%
# %pwd
# Out:
# '/Users/kravtsov777/Code/ainots/specmatan'

# %% [markdown]
# Запуск программы операционной системы

# %%
# !chcp 65001
# Out:
# zsh:1: command not found: chcp

# %%
ls
# Out:
# __pycache__/ file.py      matan1/      out1.txt     result.py

# %% [markdown]
# ### "Волшебные команды"
#
# #### Профайлинг и отладка
#
# - ```%time``` - показывает время выполнения строки кода
# - ```%%time``` - показывает время выполнения ячейки кода

# %%
enum = enumerate('hello')
enum

# %%
next(enum)
# Out:
# (0, 'h')

# %%
tuple(enum)
# Out:
# ((1, 'e'), (2, 'l'), (3, 'l'), (4, 'o'))

# %%
# Генератор в сумме
g = (x ** x for x in range(10)); g
# Out:
# <generator object <genexpr> at 0x105cc31d0>

# %%
# Метод next явно требует создать элемент из генератора
print(next(g)); 
print(next(g)); 
next(g)
# Out:
# 1
# 1
# 4

# %%
list(g)
# Out:
# [27, 256, 3125, 46656, 823543, 16777216, 387420489]

# %%
g1 = (x ** x for x in range(10)); g1
# Out:
# <generator object <genexpr> at 0x105cc32a0>

# %%
3125 in g1
# Out:
# True

# %%
for item in g1:
    print(item)
# Out:
# 46656
# 823543
# 16777216
# 387420489

# %%
# next(g1)  # StopIteration

# %%
def sum_exps( number ):
    return sum(x**x for x in range( number ))

def sum_exps_naive( number ):
    summ = 0
    for x in range(number):
        poww = x
        for y in range( x ):
            poww = poww * x
        summ += poww
    return summ

# %%
# % только для строки

# %time print("Hello World")
a = sum_exps_naive( 1000 )
b = sum_exps( 1000 )
# Out:
# Hello World
# CPU times: user 64 μs, sys: 18 μs, total: 82 μs
# Wall time: 115 μs

# %%
# %%time
print("Hello World")
a = sum_exps_naive( 1000 )
b = sum_exps( 1000 )
# Out:
# Hello World
# CPU times: user 132 ms, sys: 2.55 ms, total: 134 ms
# Wall time: 184 ms

# %%
# %time a = sum_exps_naive( 1000 )
# Out:
# CPU times: user 117 ms, sys: 2.04 ms, total: 119 ms
# Wall time: 120 ms

# %%
# %time b = sum_exps( 1000 )
# Out:
# CPU times: user 9.47 ms, sys: 313 μs, total: 9.78 ms
# Wall time: 10.9 ms

# %% [markdown]
# - ```%timeit``` - выполнить код несколько раз и показать среднее время выполнения кода. Запуск с ```%%``` приведет к "прокручиванию" кода всей клетки.
#
# Можно задать количество итерациий, запустив эту команду с параметром -nN, где N - количество циклов.

# %%
# %timeit sum_exps( 1000 )
# Out:
# 8.87 ms ± 162 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n50 -r2 sum_exps_naive( 1000 )
# Out:
# 119 ms ± 158 μs per loop (mean ± std. dev. of 2 runs, 50 loops each)

# %% [markdown]
# - ```%prun``` - построчный профайлер

# %%
# %prun sum_exps_naive( 1000 )
# Out:
#          660 function calls (654 primitive calls) in 0.213 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.093    0.047    0.019    0.019 decorator.py:232(fun)
#        14    0.086    0.006    0.086    0.006 socket.py:623(send)
#         1    0.015    0.015    0.015    0.015 1654718342.py:4(sum_exps_naive)
#         2    0.006    0.003    0.006    0.003 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.006    0.006    0.006    0.006 {method 'control' of 'select.kqueue' objects}
#       2/1    0.006    0.003    0.015    0.015 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.074    0.037 socket.py:700(send_multipart)
#         2    0.000    0.000    0.093    0.047 {method 'run' of '_contextvars.Context' objects}
#        14    0.000    0.000    0.000    0.000 enum.py:1582(__or__)
#   175/171    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#        60    0.000    0.000    0.000    0.000 enum.py:1575(_get_value)
#        26    0.000    0.000    0.000    0.000 enum.py:676(__call__)
#         1    0.000    0.000    0.019    0.019 history.py:1008(_writeout_input_cache)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.000    0.000 typing.py:184(_type_check)
#         1    0.000    0.000    0.019    0.019 history.py:1024(writeout_cache)
#         1    0.000    0.000    0.000    0.000 inspect.py:3078(_bind)
#         6    0.000    0.000    0.000    0.000 enum.py:1593(__and__)
#        26    0.000    0.000    0.000    0.000 enum.py:1145(__new__)
#         2    0.000    0.000    0.074    0.037 iostream.py:279(_really_send)
#         2    0.000    0.000    0.093    0.047 zmqstream.py:573(_handle_events)
#         2    0.000    0.000    0.093    0.047 zmqstream.py:546(_run_callback)
#         2    0.000    0.000    0.093    0.046 iostream.py:277(<lambda>)
#         1    0.000    0.000    0.006    0.006 base_events.py:1966(_run_once)
#         3    0.000    0.000    0.000    0.000 base_events.py:766(time)
#         2    0.000    0.000    0.093    0.047 iostream.py:158(_handle_event)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#         2    0.000    0.000    0.000    0.000 typing.py:1569(__subclasscheck__)
#        32    0.000    0.000    0.000    0.000 typing.py:1341(__eq__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.006    0.006 selectors.py:540(select)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 threading.py:325(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1401(_handle_fromlist)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         4    0.000    0.000    0.000    0.000 typing.py:396(inner)
#         1    0.000    0.000    0.000    0.000 inspect.py:3220(bind)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(apply_defaults)
#         2    0.000    0.000    0.093    0.047 zmqstream.py:614(_handle_recv)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 base_events.py:1951(_add_callback)
#         2    0.000    0.000    0.093    0.047 events.py:92(_run)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        12    0.000    0.000    0.000    0.000 typing.py:1347(__hash__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         6    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 queue.py:115(empty)
#         1    0.000    0.000    0.000    0.000 base_events.py:846(_call_soon)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 iostream.py:214(_is_master_process)
#         1    0.000    0.000    0.019    0.019 history.py:92(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 typing.py:1278(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 selector_events.py:744(_process_events)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.015    0.015 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2829(args)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         1    0.000    0.000    0.093    0.093 asyncio.py:206(_handle_events)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 events.py:41(__init__)
#         2    0.000    0.000    0.000    0.000 threading.py:316(__exit__)
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 typing.py:2286(cast)
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         2    0.000    0.000    0.000    0.000 iostream.py:217(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.000    0.000 base_events.py:817(call_soon)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 threading.py:313(__enter__)
#         4    0.000    0.000    0.000    0.000 typing.py:175(_type_convert)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 threading.py:322(_release_save)
#         1    0.000    0.000    0.000    0.000 inspect.py:2852(kwargs)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         1    0.000    0.000    0.000    0.000 ioloop.py:750(_run_callback)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 threading.py:641(clear)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#        10    0.000    0.000    0.000    0.000 inspect.py:2735(kind)
#         2    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 threading.py:328(_is_owned)
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         4    0.000    0.000    0.000    0.000 inspect.py:2723(name)
#         4    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2821(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:548(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:2064(get_debug)

# %% [markdown]
# Для записи в файл используем магическую команду __%%writefile__

# %%
# %%writefile file.py
line = "hello Jupyter"
print(line[::-1])
# Out:
# Overwriting file.py

# %% [markdown]
# Для загрузки файла используем магическую команду __%load__

# %%
# %load file.py
line = "hello Jupyter"
print(line[::-1])
# Out:
# retypuJ olleh

# %%
s = 'hello Jupyter'
s[-2::-1]
# Out:
# 'etypuJ olleh'

# %%
save result.py 72 73
# Out:
# '72 73' was not found in history, as a file, url, nor in the user namespace.

# %% [markdown]
# Используем механизм операционной системы. Перенаправляем стандартный поток вывода в файл out1.txt

# %%
# !python file.py > out1.txt

# %%
# %load out1.txt
retypuJ olleh
# Out:
#   Cell In[44], line 2
#     retypuJ olleh
#             ^
# SyntaxError: invalid syntax

# %%
# %%writefile file.py
def main():
    line = "hello Jupyter"
    print(line[::-1])
    print(line.capitalize())
# Out:
# Overwriting file.py

# %%
# %%prun 
for i in range(10): 
    sum_exps(1000)
# Out:
#          10703 function calls (10697 primitive calls) in 0.285 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     10010    0.153    0.000    0.153    0.000 1654718342.py:2(<genexpr>)
#       2/1    0.112    0.056    0.164    0.164 {built-in method builtins.exec}
#        14    0.008    0.001    0.068    0.005 socket.py:623(send)
#       2/1    0.005    0.002    0.044    0.044 <string>:1(<module>)
#        10    0.002    0.000    0.073    0.007 {built-in method builtins.sum}
#         1    0.001    0.001    0.012    0.012 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.005    0.003 {method '__exit__' of 'sqlite3.Connection' objects}
#   176/172    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         4    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#        10    0.000    0.000    0.139    0.014 1654718342.py:1(sum_exps)
#         1    0.000    0.000    0.003    0.003 {method 'control' of 'select.kqueue' objects}
#         6    0.000    0.000    0.000    0.000 enum.py:1593(__and__)
#         4    0.000    0.000    0.000    0.000 typing.py:396(inner)
#        14    0.000    0.000    0.000    0.000 enum.py:1582(__or__)
#        60    0.000    0.000    0.000    0.000 enum.py:1575(_get_value)
#         3    0.000    0.000    0.112    0.037 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.001    0.000 socket.py:771(recv_multipart)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        26    0.000    0.000    0.000    0.000 enum.py:676(__call__)
#         1    0.000    0.000    0.019    0.019 history.py:1024(writeout_cache)
#         1    0.000    0.000    0.007    0.007 base_events.py:1966(_run_once)
#         2    0.000    0.000    0.092    0.046 iostream.py:279(_really_send)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         4    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         4    0.000    0.000    0.000    0.000 typing.py:184(_type_check)
#        26    0.000    0.000    0.000    0.000 enum.py:1145(__new__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3078(_bind)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.111    0.055 iostream.py:277(<lambda>)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         2    0.000    0.000    0.015    0.007 socket.py:700(send_multipart)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         1    0.000    0.000    0.000    0.000 base_events.py:1951(_add_callback)
#         2    0.000    0.000    0.112    0.056 zmqstream.py:573(_handle_events)
#         2    0.000    0.000    0.111    0.056 zmqstream.py:546(_run_callback)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.111    0.056 iostream.py:158(_handle_event)
#         3    0.000    0.000    0.112    0.037 events.py:92(_run)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 iostream.py:713(_rotate_buffers)
#        32    0.000    0.000    0.000    0.000 typing.py:1341(__eq__)
#         1    0.000    0.000    0.000    0.000 threading.py:325(_acquire_restore)
#         1    0.000    0.000    0.003    0.003 selectors.py:540(select)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(apply_defaults)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 ioloop.py:750(_run_callback)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.005    0.005 history.py:1008(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         3    0.000    0.000    0.000    0.000 base_events.py:766(time)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1401(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 iostream.py:705(_flush_buffers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        12    0.000    0.000    0.000    0.000 typing.py:1347(__hash__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3220(bind)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 iostream.py:611(_flush)
#         2    0.000    0.000    0.000    0.000 typing.py:1569(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.112    0.056 zmqstream.py:614(_handle_recv)
#         2    0.000    0.000    0.000    0.000 selector_events.py:744(_process_events)
#         1    0.000    0.000    0.000    0.000 base_events.py:846(_call_soon)
#         2    0.000    0.000    0.000    0.000 iostream.py:214(_is_master_process)
#         6    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 events.py:41(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 inspect.py:2829(args)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.019    0.019 decorator.py:232(fun)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         4    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.019    0.019 history.py:92(only_when_enabled)
#         4    0.000    0.000    0.000    0.000 typing.py:175(_type_convert)
#         1    0.000    0.000    0.000    0.000 threading.py:641(clear)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 typing.py:1278(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 threading.py:316(__exit__)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 queue.py:115(empty)
#         1    0.000    0.000    0.112    0.112 asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.000    0.000 base_events.py:817(call_soon)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#        20    0.000    0.000    0.000    0.000 typing.py:2286(cast)
#         1    0.000    0.000    0.000    0.000 events.py:162(__lt__)
#         1    0.000    0.000    0.000    0.000 threading.py:322(_release_save)
#         2    0.000    0.000    0.000    0.000 threading.py:313(__enter__)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         5    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2852(kwargs)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:217(_check_mp_mode)
#        10    0.000    0.000    0.000    0.000 inspect.py:2735(kind)
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#         4    0.000    0.000    0.000    0.000 inspect.py:2723(name)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:328(_is_owned)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 base_events.py:548(_check_closed)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2821(__init__)
#         2    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:2064(get_debug)

# %%
from IPython.display import display, Image, HTML, Math
Image(url='https://python.org/images/python-logo.gif')
# Out:
# <img src="https://python.org/images/python-logo.gif"/>

# %% [markdown]
# ### Другие полезные "волшебные" функции
#
# Справка по всем "магическим" функциям - ```%magic```

# %%
# список объявленных переменных
# %who
# Out:
# HTML	 Image	 Math	 a	 b	 display	 enum	 g	 g1
# i	 item	 line	 math	 mul_numbers	 rnd	 s	 sum_exps	 sum_exps_naive

# %%
# %whos
# Out:
# Variable         Type         Data/Info
# ---------------------------------------
# HTML             type         <class 'IPython.core.display.HTML'>
# Image            type         <class 'IPython.core.display.Image'>
# Math             type         <class 'IPython.core.display.Math'>
# a                int          3678308098439971776579901<...>7229025779686886423427700
# b                int          3681991446951770953750112<...>2350667978127819110846701
# display          function     <function display at 0x105359900>
# enum             enumerate    <enumerate object at 0x107a83ec0>
# g                generator    <generator object <genexpr> at 0x107a4a190>
# g1               generator    <generator object <genexpr> at 0x107a48450>
# i                int          9
# item             int          387420489
# line             str          hello Jupyter
# math             module       <module 'math' from '/opt<...>h.cpython-314-darwin.so'>
# mul_numbers      function     <function mul_numbers at 0x107aa6820>
# rnd              module       <module 'random' from '/o<...>ib/python3.14/random.py'>
# s                str          hello Jupyter
# sum_exps         function     <function sum_exps at 0x1079b7ed0>
# sum_exps_naive   function     <function sum_exps_naive at 0x107a58460>

# %%
# показать историю команд
# %hist
# Out:
# print(b)
# b = [1, 2, 3, 4, 5]
# s = 'Hello'
# s
# print(s); b
# print(b)
# b?
# b?
# s = 'Hello!!'
# s
# mul_numbers(34, 3.1)
# # Использую хинтинг(hinting). С версию 3.9
# def mul_numbers(a: float | int, b: float | int) -> float:
#     """  Функция умножает два числа """
#     return a * b
# mul_numbers(34, 3.1)
# mul_numbers(34, 3.1)
# mul_numbers(34, 3.1)
# b = [1, 2, 3, 4, 5]
# s = 'Hello!!'
# s
# print(s); b
# print(b)
# b?
# # Использую хинтинг(hinting). С версию 3.9
# def mul_numbers(a: float | int, b: float | int) -> float:
#     """  Функция умножает два числа """
#     return a * b
# b = [1, 2, 3, 4, 5]
# s = 'Hello!!'
# s
# print(s); b
# print(b)
# b?
# # Использую хинтинг(hinting). С версию 3.9
# def mul_numbers(a: float | int, b: float | int) -> float:
#     """  Функция умножает два числа """
#     return a * b
# mul_numbers(34, 3.1)
# # mul_numbers('1', '1')  # TypeError
# mul_numbers?
# # два знака вопроса откроют окно с исходным кодом
# mul_numbers??
# import random as rnd
# rnd.randint??
# import math
# math.sin??
# lsmagic
# print("C:\\name")
# %pwd
# %cd /Users/kravtsov777/Code/ainots/specmatan
# %pwd
# !chcp 65001
# ls
# enum = enumerate('hello')
# enum
# next(enum)
# tuple(enum)
# # Генератор в сумме
# g = (x ** x for x in range(10)); g
# # Метод next явно требует создать элемент из генератора
# print(next(g));
# print(next(g));
# next(g)
# list(g)
# g1 = (x ** x for x in range(10)); g1
# 3125 in g1
# for item in g1:
#     print(item)
# # next(g1)  # StopIteration
# def sum_exps( number ):
#     return sum(x**x for x in range( number ))
#
# def sum_exps_naive( number ):
#     summ = 0
#     for x in range(number):
#         poww = x
#         for y in range( x ):
#             poww = poww * x
#         summ += poww
#     return summ
# # % только для строки
#
# %time print("Hello World")
# a = sum_exps_naive( 1000 )
# b = sum_exps( 1000 )
# %%time
# print("Hello World")
# a = sum_exps_naive( 1000 )
# b = sum_exps( 1000 )
# %time a = sum_exps_naive( 1000 )
# %time b = sum_exps( 1000 )
# %timeit sum_exps( 1000 )
# %timeit -n50 -r2 sum_exps_naive( 1000 )
# %prun sum_exps_naive( 1000 )
# %%writefile file.py
# line = "hello Jupyter"
# print(line[::-1])
# # %load file.py
# line = "hello Jupyter"
# print(line[::-1])
# s = 'hello Jupyter'
# s[-2::-1]
# save result.py 72 73
# !python file.py > out1.txt
# # %load out1.txt
# retypuJ olleh
# b = [1, 2, 3, 4, 5]
# s = 'Hello!!'
# s
# print(s); b
# print(b)
# b?
# # Использую хинтинг(hinting). С версию 3.9
# def mul_numbers(a: float | int, b: float | int) -> float:
#     """  Функция умножает два числа """
#     return a * b
# mul_numbers(34, 3.1)
# # mul_numbers('1', '1')  # TypeError
# mul_numbers?
# # два знака вопроса откроют окно с исходным кодом
# mul_numbers??
# import random as rnd
# rnd.randint??
# import math
# math.sin??
# lsmagic
# print("C:\\name")
# %pwd
# %cd /Users/kravtsov777/Code/ainots/specmatan
# %pwd
# !chcp 65001
# ls
# enum = enumerate('hello')
# enum
# next(enum)
# tuple(enum)
# # Генератор в сумме
# g = (x ** x for x in range(10)); g
# # Метод next явно требует создать элемент из генератора
# print(next(g));
# print(next(g));
# next(g)
# list(g)
# g1 = (x ** x for x in range(10)); g1
# 3125 in g1
# for item in g1:
#     print(item)
# # next(g1)  # StopIteration
# def sum_exps( number ):
#     return sum(x**x for x in range( number ))
#
# def sum_exps_naive( number ):
#     summ = 0
#     for x in range(number):
#         poww = x
#         for y in range( x ):
#             poww = poww * x
#         summ += poww
#     return summ
# # % только для строки
#
# %time print("Hello World")
# a = sum_exps_naive( 1000 )
# b = sum_exps( 1000 )
# %%time
# print("Hello World")
# a = sum_exps_naive( 1000 )
# b = sum_exps( 1000 )
# %time a = sum_exps_naive( 1000 )
# %time b = sum_exps( 1000 )
# %timeit sum_exps( 1000 )
# %timeit -n50 -r2 sum_exps_naive( 1000 )
# %prun sum_exps_naive( 1000 )
# %%writefile file.py
# line = "hello Jupyter"
# print(line[::-1])
# # %load file.py
# line = "hello Jupyter"
# print(line[::-1])
# s = 'hello Jupyter'
# s[-2::-1]
# save result.py 72 73
# !python file.py > out1.txt
# %load out1.txt
# # retypuJ olleh
# %%writefile file.py
# def main():
#     line = "hello Jupyter"
#     print(line[::-1])
#     print(line.capitalize())
# %%prun
# for i in range(10):
#     sum_exps(1000)
# from IPython.display import display, Image, HTML, Math
# Image(url='https://python.org/images/python-logo.gif')
# # список объявленных переменных
# %who
# %whos
# # показать историю команд
# %hist

# %%
# текущий каталог можно узнать через команду %pwd
x = %pwd
x
# Out:
# '/Users/kravtsov777/Code/ainots/specmatan'

# %%
# удалить переменную и попытаться очистить все ссылки на объект во внутреннем пространстве имен Jupyter Notebook
# %xdel line

# %%
who
# Out:
# HTML	 Image	 Math	 a	 b	 display	 enum	 g	 g1
# i	 item	 math	 mul_numbers	 rnd	 s	 sum_exps	 sum_exps_naive	 x

# %%
# удалить все переменные
# %reset

# %%
who
# Out:
# Interactive namespace is empty.

# %% [markdown]
# ### Подключение внешних модулей
#
# 1. Если ```import module``` не может найти нужный модуль, используйте ```pip install ...``` или ```conda install ...```__ВНЕ ТЕТРАДИ__, то есть в командной строке.
# 2. Запуск ```!pip install``` установит запрашиваемый модуль только для текущего сеанса.
# 3. Если вы разрабатываете свой модуль во внешнем редакторе, а отлаживаете его в Jupyter, включите автообновление модуля по мере его сохранения:
# ```python
# %load_ext autoreload
# %autoreload 2
# ```

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %autoreload?
# Out:
# Docstring:
# ::
#
#   %autoreload [-p] [-l] [--hide-errors] [--full] [mode]
#
# %autoreload => Reload modules automatically
#
# %autoreload or %autoreload now
# Reload all modules (except those excluded by %aimport) automatically
# now.
#
# %autoreload 0 or %autoreload off
# Disable automatic reloading.
#
# %autoreload 1 or %autoreload explicit
# Reload only modules imported with %aimport every time before executing
# the Python code typed.
#
# %autoreload 2 or %autoreload all
# Reload all modules (except those excluded by %aimport) every time
# before executing the Python code typed.
#
# %autoreload 3 or %autoreload complete
# Same as 2/all, but also but also adds any new objects in the module. See
# unit test at IPython/extensions/tests/test_autoreload.py::test_autoload_newly_added_objects
#
# The optional arguments --print and --log control display of autoreload activity. The default
# is to act silently; --print (or -p) will print out the names of modules that are being
# reloaded, and --log (or -l) outputs them to the log at INFO level.
#
# The optional argument --hide-errors hides any errors that can happen when trying to
# reload code.
#
# Reloading Python modules in a reliable way is in general
# difficult, and unexpected things may occur. %autoreload tries to
# work around common pitfalls by replacing function code objects and
# parts of classes previously in the module with new versions. This
# makes the following things to work:
#
# - Functions and classes imported via 'from xxx import foo' are upgraded
#   to new versions when 'xxx' is reloaded.
#
# - Methods and properties of classes are upgraded on reload, so that
#   calling 'c.foo()' on an object 'c' created before the reload causes
#   the new code for 'foo' to be executed.
#
# Some of the known remaining caveats are:
#
# - Replacing code objects does not always succeed: changing a @property
#   in a class to an ordinary method or a method to a member variable
#   can cause problems (but in old objects only).
#
# - Functions that are removed (eg. via monkey-patching) from a module
#   before it is reloaded are not upgraded.
#
# - C extension modules cannot be reloaded, and so cannot be
#   autoreloaded.
#
# positional arguments:
#   mode           blank or 'now' - Reload all modules (except those excluded by
#                  %aimport) automatically now. '0' or 'off' - Disable automatic
#                  reloading. '1' or 'explicit' - Reload only modules imported
#                  with %aimport every time before executing the Python code
#                  typed. '2' or 'all' - Reload all modules (except those
#                  excluded by %aimport) every time before executing the Python
#                  code typed. '3' or 'complete' - Same as 2/all, but also adds
#                  any new objects in the module. By default, a newer autoreload
#                  algorithm that diffs the module's source code with the
#                  previous version and only reloads changed parts is applied
#                  for modes 2 and below. To use the original algorithm, add the
#                  `-` suffix to the mode, e.g. '{'option_strings': [], 'dest':
#                  'mode', 'nargs': '?', 'const': None, 'default': 'now',
#                  'type': 'str', 'choices': None, 'required': False, 'help':
#                  "blank or 'now' - Reload all modules (except those excluded
#                  by %%aimport)\n automatically now.\n\n '0' or 'off' - Disable
#                  automatic reloading.\n\n '1' or 'explicit' - Reload only
#                  modules imported with %%aimport every\n time before executing
#                  the Python code typed.\n\n '2' or 'all' - Reload all modules
#                  (except those excluded by %%aimport)\n every time before
#                  executing the Python code typed.\n\n '3' or 'complete' - Same
#                  as 2/all, but also adds any new\n objects in the module.\n \n
#                  By default, a newer autoreload algorithm that diffs the
#                  module's source code\n with the previous version and only
#                  reloads changed parts is applied for modes\n 2 and below. To
#                  use the original algorithm, add the `-` suffix to the mode,\n
#                  e.g. '%autoreload 2-', or pass in --full.\n ", 'metavar':
#                  None, 'deprecated': False, 'container':
#                  <argparse._ArgumentGroup object at 0x107172e10>, 'prog':
#                  'autoreload'}utoreload 2-', or pass in --full.
#
# options:
#   -p, --print    Show autoreload activity using `print` statements
#   -l, --log      Show autoreload activity using the logger
#   --hide-errors  Hide autoreload errors
#   --full         Don't ever use new diffing algorithm
# File:      /opt/anaconda3/envs/matan/lib/python3.14/site-packages/IPython/extensions/autoreload.py

# %%
import file

# %%
file.main()
# Out:
# retypuJ olleh
# Hello jupyter

# %% [markdown]
# ## Язык Markdown
#
# Чтобы редактировать содержимое Markdown-клетки, дважды кликните по ней.

# %% [markdown]
# # Заголовок 1
#
# ## Заголовок 2
#
# ### _Заголовок 3_
#
# Quick brown fox __jumped__ _over_ lazy dog. Quick brown fox jumped over lazy dog.Quick brown fox jumped over lazy dog.Quick brown fox jumped over lazy dog.Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
#
# Quick brown fox jumped over lazy https://www.dogs.com/. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
#
# 1. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
# 2. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
# 1. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
#
# $\begin{cases}
# 2 + t^1*2 = 0 + t_2*(-1) \\
# 3 + t_1*1 = 1 + t_2*1
# \end{cases}
# $
