# %% [markdown]
# ### Домашнее задание

# %% [markdown]
# #### Задание №1
# <font size='4'>Найти производную первого порядка следующих функций: </font>

# %% [markdown]
# <font size='5'>$f(x) = \frac{3^x+5}{cos(x)}$ </font>

# %% [markdown]
# <font size='5'>$f(x) = \frac{1+x^2}{1-x^2}$ </font>

# %% [markdown]
# <font size='4'>$f(x) = -2xe^{3x}+(x^2-4x+3)sin7x$ </font>

# %% [markdown]
# #### Задание №2
# <font size='4'>Найти первую и вторую производные функции и построить их графики.  </font>
# <font size='4'> Пример 1. $f(x) = e^{tg3x}$ </font>
# <font size='4'> Пример 2. $f(x) = x^3-4x+13$ </font>

# %% [markdown]
# #### Задание №3

# %% [markdown]
# <font size='4'>Найти производную десятого порядка $y^{(10)}$ для функции: $ y=ln(2x-1)$ </font>

# %%
import sympy as sp

# %%
sp.var('x')
func = 3 ** x + 5 / sp.cos(x)
dfunc = sp.diff(func, x)
dfunc
# Out:
# 3**x*log(3) + 5*sin(x)/cos(x)**2

# %%
# sp.var('x')
func = -2 * x * sp.exp(3*x) + (x ** 2 + 4 * x + 3)*sp.sin(7*x)
dfunc = sp.diff(func, x)
dfunc
# Out:
# -6*x*exp(3*x) + (2*x + 4)*sin(7*x) + 7*(x**2 + 4*x + 3)*cos(7*x) - 2*exp(3*x)

# %%
# sp.var('x')
func = x ** 3 - 4 * x + 13
dfunc = sp.diff(func, x)
dfunc1 = sp.diff(func, x, 2)

dfunc
dfunc1
# Out:
# 6*x

# %%
from sympy.plotting import plot

# %%
plot(func, dfunc, (x, 0, 2.5));
plot(func, dfunc1, (x, 0, 2.5));

# %%
# sp.var('x') 
y = sp.ln(2 * x -1)
dfunc = sp.diff(y, x, 10)
dfunc
# Out:
# -371589120/(2*x - 1)**10

# %%
# sp.var('x')
# sp.var('e')
sp.var('t')
sp.var('g')
func = sp.exp(t * g * 3 * x)
dfunc2 = sp.diff(func, x)
dfunc3 = sp.diff(func, x, 2)

dfunc2
dfunc3
# Out:
# 9*g**2*t**2*exp(3*g*t*x)

# %%
xdel e

# %%
whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# dfunc      Mul         -371589120/(2*x - 1)**10
# dfunc1     Mul         6*x
# dfunc2     Mul         3*g*t*exp(3*g*t*x)
# dfunc3     Mul         9*g**2*t**2*exp(3*g*t*x)
# func       exp         exp(3*g*t*x)
# g          Symbol      g
# plot       function    <function plot at 0x000001E702DB85E0>
# sp         module      <module 'sympy' from 'C:\<...>ges\\sympy\\__init__.py'>
# t          Symbol      t
# x          Symbol      x
# y          log         log(2*x - 1)

# %%
sp.plotting.plot3d(func, dfunc2, (x, 0, 1.5), (t, 0, 1.5), (g, 0, 1.5));
# plot(func, dfunc3, (x, 0, 1.5));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sp.plotting.plot3d(func, dfunc2, (x, 0, 1.5), (t, 0, 1.5), (g, 0, 1.5));
#       2 # plot(func, dfunc3, (x, 0, 1.5));
#
# File ~\anaconda3\envs\m1_main\Lib\site-packages\sympy\plotting\plot.py:2323, in plot3d(show, *args, **kwargs)
#    2321 args = list(map(sympify, args))
#    2322 series = []
# -> 2323 plot_expr = check_arguments(args, 1, 2)
#    2324 series = [SurfaceOver2DRangeSeries(*arg, **kwargs) for arg in plot_expr]
#    2325 kwargs.setdefault("xlabel", series[0].var_x)
#
# File ~\anaconda3\envs\m1_main\Lib\site-packages\sympy\plotting\plot.py:2606, in check_arguments(args, expr_len, nb_of_free_symbols)
#    2602 free_symbols = list(set().union(*[e.free_symbols for expr in exprs
#    2603                                 for e in expr]))
#    2605 if len(free_symbols) > nb_of_free_symbols:
# -> 2606     raise ValueError("The number of free_symbols in the expression "
#    2607                      "is greater than %d" % nb_of_free_symbols)
#    2608 if len(args) == i + nb_of_free_symbols and isinstance(args[i], Tuple):
#    2609     ranges = Tuple(*list(args[
#    2610                    i:i + nb_of_free_symbols]))
#
# ValueError: The number of free_symbols in the expression is greater than 2
