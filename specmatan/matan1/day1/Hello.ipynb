# %% [markdown]
# # Курс "Mатематический анализ. Часть 1"
#
# Если вы читаете эти строки, значит вы успешно установили и запустили Jupyter Notebook.
#
# ##  Особенности работы в Jupyter Notebook
#
# 1. Код пишется в "клетках" ```In []:```, результат исполнения - в "клетках" ```Out []:```.
# 2. Stack Trace тоже отображается в клетках ```Out []:```.
# 2. Цифра в квадратных скобках - порядковый номер исполнения данного фрагмента кода.
# 2. Запуск кода: ```Shift - Enter``` - с переходом в следующую "клетку", ```Ctrl - Enter``` - без оного.
# 3. Все переменные, объявленные в "клетке" становятся видимыми внутри всей тетрадки.
# 4. Все переменные, объявленные в тетрадке, видимы только внутри нее и не влияют на другие открытые тетрадки.
#
# ### Если "Что-то пошло не так..."
#
# 1. ```Ctrl - C``` прервет выполнение кода исключением ```KeyboardInterrupt```
# 1. Если это не помогает - надо перезапустить ядро (меню Kernel / Restart), и потом последовательно выполнить все предыдущие "клетки".
# 2. Если и это не помогает - снимите процесс python.
#
#
# ### Синтаксис Python в Jupyter Notebook
#
# 1. Есть подсветка синтаксиса.
# 2. Отступы проставляются автоматически, можно использовать tab.
# 3. По нажатию tab - автозаполнение.
# 4. Символ "?", указанный до или после переменной, открывает окно с информацией о ней (будь это просто переменная или функция).
# 5. Закомментировать строку можно сочетанием клавиш ```Ctrl - /```.

# %%
b = [1, 2, 3, 4, 5]

# %%
s = 'Hello!!'
s
# Out:
# 'Hello!!'

# %%
print(s); b
# Out:
# Hello!!
# [1, 2, 3, 4, 5]

# %%
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
b?
# Out:
# Type:        list
# String form: [1, 2, 3, 4, 5]
# Length:      5
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
# Использую хинтинг(hinting). С версию 3.9 
def mul_numbers(a: float | int, b: float | int) -> float:
    """  Функция умножает два числа """
    return a * b

# %%
mul_numbers(34, 3.1)
# Out:
# 105.4

# %%
# mul_numbers('1', '1')  # TypeError

# %%
mul_numbers?
# Out:
# Signature: mul_numbers(a: float | int, b: float | int) -> float
# Docstring: Функция умножает два числа
# File:      /var/folders/zk/wc07fm1d6sx_8362cmm1sh1xybjh0x/T/ipykernel_2659/2769045436.py
# Type:      function

# %%
# два знака вопроса откроют окно с исходным кодом
mul_numbers??
# Out:
# Signature: mul_numbers(a: float | int, b: float | int) -> float
# Source:
# def mul_numbers(a: float | int, b: float | int) -> float:
#     """  Функция умножает два числа """
#     return a * b
# File:      /var/folders/zk/wc07fm1d6sx_8362cmm1sh1xybjh0x/T/ipykernel_2659/2769045436.py
# Type:      function

# %%
import random as rnd

# %%
rnd.randint??
# Out:
# Signature: rnd.randint(a, b)
# Docstring:
# Return random integer in range [a, b], including both end points.
#
# Source:
#     def randint(self, a, b):
#         """Return random integer in range [a, b], including both end points.
#         """
#
#         return self.randrange(a, b+1)
# File:      /opt/anaconda3/envs/matancode/lib/python3.13/random.py
# Type:      method

# %%
import math
math.sin??
# Out:
# Signature: math.sin(x, /)
# Docstring: Return the sine of x (measured in radians).
# Type:      builtin_function_or_method

# %% [markdown]
# ### Список магических команд

# %%
lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# Пример `latex`:

# %% [markdown]
# $$
# f_i = \frac{3}{4}
# $$

# %%
print("C:\\name")
# Out:
# C:\name

# %%
# %pwd
# Out:
# '/Users/kravtsov777/Code/ainots/specmatan/matan1/day1'

# %%
# %cd /Users/kravtsov777/Code/ainots/specmatan
# Out:
# /Users/kravtsov777/Code/ainots/specmatan

# %%
# %pwd
# Out:
# '/Users/kravtsov777/Code/ainots/specmatan'

# %% [markdown]
# Запуск программы операционной системы

# %%
# !chcp 65001
# Out:
# zsh:1: command not found: chcp

# %%
ls
# Out:
# matan1/

# %% [markdown]
# ### "Волшебные команды"
#
# #### Профайлинг и отладка
#
# - ```%time``` - показывает время выполнения строки кода
# - ```%%time``` - показывает время выполнения ячейки кода

# %%
enum = enumerate('hello')
enum

# %%
next(enum)
# Out:
# (0, 'h')

# %%
tuple(enum)
# Out:
# ((1, 'e'), (2, 'l'), (3, 'l'), (4, 'o'))

# %%
# Генератор в сумме
g = (x ** x for x in range(10)); g
# Out:
# <generator object <genexpr> at 0x1083c1970>

# %%
# Метод next явно требует создать элемент из генератора
print(next(g)); 
print(next(g)); 
next(g)
# Out:
# 1
# 1
# 4

# %%
list(g)
# Out:
# [27, 256, 3125, 46656, 823543, 16777216, 387420489]

# %%
g1 = (x ** x for x in range(10)); g1
# Out:
# <generator object <genexpr> at 0x1083c1b10>

# %%
3125 in g1
# Out:
# True

# %%
for item in g1:
    print(item)
# Out:
# 46656
# 823543
# 16777216
# 387420489

# %%
# next(g1)  # StopIteration

# %%
def sum_exps( number ):
    return sum(x**x for x in range( number ))

def sum_exps_naive( number ):
    summ = 0
    for x in range(number):
        poww = x
        for y in range( x ):
            poww = poww * x
        summ += poww
    return summ

# %%
# % только для строки

# %time print("Hello World")
a = sum_exps_naive( 1000 )
b = sum_exps( 1000 )
# Out:
# Hello World
# CPU times: user 225 μs, sys: 312 μs, total: 537 μs
# Wall time: 2.43 ms

# %%
# %%time
print("Hello World")
a = sum_exps_naive( 1000 )
b = sum_exps( 1000 )
# Out:
# Hello World
# CPU times: user 121 ms, sys: 1.33 ms, total: 123 ms
# Wall time: 123 ms

# %%
# %time a = sum_exps_naive( 1000 )
# Out:
# CPU times: user 113 ms, sys: 1.41 ms, total: 115 ms
# Wall time: 115 ms

# %%
# %time b = sum_exps( 1000 )
# Out:
# CPU times: user 8.6 ms, sys: 322 μs, total: 8.92 ms
# Wall time: 8.73 ms

# %% [markdown]
# - ```%timeit``` - выполнить код несколько раз и показать среднее время выполнения кода. Запуск с ```%%``` приведет к "прокручиванию" кода всей клетки.
#
# Можно задать количество итерациий, запустив эту команду с параметром -nN, где N - количество циклов.

# %%
# %timeit sum_exps( 1000 )
# Out:
# 9.64 ms ± 654 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n50 -r2 sum_exps_naive( 1000 )
# Out:
# 118 ms ± 2.04 ms per loop (mean ± std. dev. of 2 runs, 50 loops each)

# %% [markdown]
# - ```%prun``` - построчный профайлер

# %%
# %prun sum_exps_naive( 1000 )
# Out:
#          556 function calls (550 primitive calls) in 0.214 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.095    0.047    0.019    0.019 decorator.py:232(fun)
#        14    0.082    0.006    0.082    0.006 socket.py:623(send)
#         1    0.013    0.013    0.013    0.013 1654718342.py:4(sum_exps_naive)
#         1    0.006    0.006    0.006    0.006 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.006    0.003    0.006    0.003 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.006    0.006    0.006    0.006 {method 'control' of 'select.kqueue' objects}
#       2/1    0.005    0.002    0.013    0.013 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.076    0.038 socket.py:700(send_multipart)
#        14    0.000    0.000    0.000    0.000 enum.py:1596(__or__)
#         2    0.000    0.000    0.095    0.047 {method 'run' of '_contextvars.Context' objects}
#        60    0.000    0.000    0.000    0.000 enum.py:1589(_get_value)
#   131/127    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#        26    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#         1    0.000    0.000    0.019    0.019 history.py:1008(_writeout_input_cache)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         2    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#         1    0.000    0.000    0.019    0.019 history.py:1024(writeout_cache)
#         1    0.000    0.000    0.000    0.000 inspect.py:3157(_bind)
#        26    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#         6    0.000    0.000    0.000    0.000 enum.py:1607(__and__)
#         1    0.000    0.000    0.006    0.006 base_events.py:1970(_run_once)
#         6    0.000    0.000    0.000    0.000 typing.py:426(inner)
#         2    0.000    0.000    0.095    0.047 iostream.py:158(_handle_event)
#         2    0.000    0.000    0.095    0.047 iostream.py:277(<lambda>)
#         2    0.000    0.000    0.095    0.047 zmqstream.py:546(_run_callback)
#         2    0.000    0.000    0.076    0.038 iostream.py:279(_really_send)
#         2    0.000    0.000    0.095    0.047 zmqstream.py:573(_handle_events)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         1    0.000    0.000    0.006    0.006 selectors.py:540(select)
#         2    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#         2    0.000    0.000    0.095    0.047 zmqstream.py:614(_handle_recv)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 inspect.py:2971(apply_defaults)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3299(bind)
#         2    0.000    0.000    0.000    0.000 queue.py:112(empty)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.095    0.047 events.py:87(_run)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 base_events.py:772(time)
#         1    0.000    0.000    0.019    0.019 history.py:92(only_when_enabled)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2941(kwargs)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         2    0.000    0.000    0.000    0.000 iostream.py:214(_is_master_process)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         4    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2918(args)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        20    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#         2    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#         1    0.000    0.000    0.095    0.095 asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.000    0.000 base_events.py:1955(_add_callback)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.013    0.013 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#         2    0.000    0.000    0.000    0.000 iostream.py:217(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 ioloop.py:750(_run_callback)
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 threading.py:631(clear)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        10    0.000    0.000    0.000    0.000 inspect.py:2828(kind)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 queue.py:266(_qsize)
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         2    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2816(name)
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         4    0.000    0.000    0.000    0.000 inspect.py:3111(parameters)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:2068(get_debug)
#         1    0.000    0.000    0.000    0.000 inspect.py:2910(__init__)

# %% [markdown]
# Для записи в файл используем магическую команду __%%writefile__

# %%
# %%writefile file.py
line = "hello Jupyter"
print(line[::-1])
# Out:
# Writing file.py

# %% [markdown]
# Для загрузки файла используем магическую команду __%load__

# %%
# %load file.py
line = "hello Jupyter"
print(line[::-1])
# Out:
# retypuJ olleh

# %%
s = 'hello Jupyter'
s[-2::-1]
# Out:
# 'etypuJ olleh'

# %%
save result.py 49 50
# Out:
# The following commands were written to file `result.py`:
# # %load file.py
# line = "hello Jupyter"
# print(line[::-1])
# s = 'hello Jupyter'
# s[-2::-1]

# %% [markdown]
# Используем механизм операционной системы. Перенаправляем стандартный поток вывода в файл out1.txt

# %%
# !python file.py > out1.txt

# %%
# %load out1.txt
retypuJ olleh

# %%
# %%writefile file2.py
def main():
    line = "hello Jupyter"
    print(line[::-1])
    print(line.capitalize())
# Out:
# Writing file2.py

# %%
# %%prun 
for i in range(10): 
    sum_exps(1000)
# Out:
#          10474 function calls (10470 primitive calls) in 0.296 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.138    0.069    0.142    0.142 {built-in method builtins.exec}
#     10010    0.132    0.000    0.132    0.000 1654718342.py:2(<genexpr>)
#         2    0.018    0.009    0.133    0.067 iostream.py:277(<lambda>)
#        14    0.006    0.000    0.073    0.005 socket.py:623(send)
#        10    0.001    0.000    0.030    0.003 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#        10    0.000    0.000    0.094    0.009 1654718342.py:1(sum_exps)
#         2    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.015    0.008 {method '__exit__' of 'sqlite3.Connection' objects}
#        48    0.000    0.000    0.000    0.000 enum.py:1589(_get_value)
#        13    0.000    0.000    0.000    0.000 enum.py:1596(__or__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#   106/104    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.016    0.016 history.py:1008(_writeout_input_cache)
#         2    0.000    0.000    0.100    0.050 iostream.py:279(_really_send)
#        19    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#         2    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3157(_bind)
#         1    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#        19    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#         2    0.000    0.000    0.000    0.000 iostream.py:214(_is_master_process)
#         1    0.000    0.000    0.016    0.016 history.py:1024(writeout_cache)
#         1    0.000    0.000    0.133    0.133 iostream.py:158(_handle_event)
#         3    0.000    0.000    0.000    0.000 enum.py:1607(__and__)
#         1    0.000    0.000    0.134    0.134 zmqstream.py:573(_handle_events)
#         1    0.000    0.000    0.134    0.134 asyncio.py:206(_handle_events)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#       2/1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#         2    0.000    0.000    0.010    0.005 socket.py:700(send_multipart)
#         3    0.000    0.000    0.000    0.000 typing.py:426(inner)
#         1    0.000    0.000    0.000    0.000 inspect.py:3299(bind)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.133    0.133 zmqstream.py:546(_run_callback)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.016    0.016 history.py:92(only_when_enabled)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 inspect.py:2971(apply_defaults)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.016    0.016 decorator.py:232(fun)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.134    0.134 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#         1    0.000    0.000    0.000    0.000 base_events.py:772(time)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2918(args)
#         1    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         1    0.000    0.000    0.000    0.000 queue.py:112(empty)
#         2    0.000    0.000    0.000    0.000 iostream.py:217(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 base_events.py:1955(_add_callback)
#         1    0.000    0.000    0.134    0.134 events.py:87(_run)
#        19    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.133    0.133 zmqstream.py:614(_handle_recv)
#         1    0.000    0.000    0.000    0.000 inspect.py:2941(kwargs)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 threading.py:631(clear)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2828(kind)
#         1    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         2    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         4    0.000    0.000    0.000    0.000 inspect.py:3111(parameters)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2816(name)
#         1    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         1    0.000    0.000    0.000    0.000 queue.py:266(_qsize)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2910(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:2068(get_debug)

# %%
from IPython.display import display, Image, HTML, Math
Image(url='https://python.org/images/python-logo.gif')
# Out:
# <img src="https://python.org/images/python-logo.gif"/>

# %% [markdown]
# ### Другие полезные "волшебные" функции
#
# Справка по всем "магическим" функциям - ```%magic```

# %%
# список объявленных переменных
# %who

# %%
# %whos

# %%
# показать историю команд
# %hist

# %%
# текущий каталог можно узнать через команду %pwd
x = %pwd
x

# %%
# удалить переменную и попытаться очистить все ссылки на объект во внутреннем пространстве имен Jupyter Notebook
# %xdel line

# %%
who

# %%
# удалить все переменные
# %reset

# %%
who

# %% [markdown]
# ### Подключение внешних модулей
#
# 1. Если ```import module``` не может найти нужный модуль, используйте ```pip install ...``` или ```conda install ...```__ВНЕ ТЕТРАДИ__, то есть в командной строке.
# 2. Запуск ```!pip install``` установит запрашиваемый модуль только для текущего сеанса.
# 3. Если вы разрабатываете свой модуль во внешнем редакторе, а отлаживаете его в Jupyter, включите автообновление модуля по мере его сохранения:
# ```python
# %load_ext autoreload
# %autoreload 2
# ```

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %autoreload?

# %%
import file

# %%
file.main()

# %% [markdown]
# ## Язык Markdown
#
# Чтобы редактировать содержимое Markdown-клетки, дважды кликните по ней.

# %% [markdown]
# # Заголовок 1
#
# ## Заголовок 2
#
# ### _Заголовок 3_
#
# Quick brown fox __jumped__ _over_ lazy dog. Quick brown fox jumped over lazy dog.Quick brown fox jumped over lazy dog.Quick brown fox jumped over lazy dog.Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
#
# Quick brown fox jumped over lazy https://www.dogs.com/. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
#
# 1. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
# 2. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
# 1. Quick brown fox jumped over lazy dog. Quick brown fox jumped over lazy dog.
#
# $\begin{cases}
# 2 + t^1*2 = 0 + t_2*(-1) \\
# 3 + t_1*1 = 1 + t_2*1
# \end{cases}
# $
