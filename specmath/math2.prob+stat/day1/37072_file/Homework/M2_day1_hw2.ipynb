# %% [markdown]
# ### Упражнения

# %% [markdown]
# __Задача 1__
#
# Из колоды в 52 карты вынимают случайным образом 4 карты.
# a) Найти вероятность того, что все карты – крести.
# b) Найти вероятность того, что все карты одной масти.
# б) Найти вероятность того, что был вытянут хотя бы один туз.

# %%
# a) все крести
# сначала крестей 13, всего карт 52
13/52 * 12/51 * 11/50 * 10/49
# Out:
# 0.0026410564225690276

# %%
# б) все одной масти
# вероятность вытащить 4 карты 1-й любой масти
singlesuit = 13/52 * 12/51 * 11/50 * 10/49

# мастей 4
4 * singlesuit
# Out:
# 0.01056422569027611

# %%
# в) найдём через обратное - не вытянут ни один туз, сначала 48 не тузов
noaces = 48/52 * 47/51 * 46/50 * 45/49
1 - noaces
# Out:
# 0.2812632745405854

# %% [markdown]
# __Задача 2__
#
# В лифт семиэтажного дома на первом этаже вошли три человека.
# Каждый из них с одинаковой вероятностью выходит на любом из этажей, начиная со второго.
# Найти вероятности следующих событий:
# А — все пассажиры выйдут на четвертом этаже;
# В — все пассажиры выйдут одновременно (на одном и том же этаже);
# С — все пассажиры выйдут на разных этажах.

# %%
# A) Все пассажиры выйдут на четвертом этаже
1/7 * 1/7 * 1/7
# Out:
# 0.0029154518950437317

# %%
# B) Все пассажиры выйдут одновременно (на одном и том же этаже);
single_floor_prob = 1/7 * 1/7 * 1/7
any_floor_prob = single_floor_prob * 7
any_floor_prob
# Out:
# 0.02040816326530612

# %%
# С) все пассажиры выйдут на разных этажах.
7/7 * 6/7 * 5/7
# Out:
# 0.6122448979591837

# %% [markdown]
# __Задача 3__
#
# Из 60 вопросов, входящих в экзаменационные билеты, студент знает 50. Какова вероятность того, что среди трёх наугад выбранных вопросов студент знает: а) все? б) два?

# %%
# a) все
50/60 * 49/59 * 48/58
# Out:
# 0.5727644652250147

# %%
# б) два
a = 50/60 * 49/59 * 10/58 # знает 1-й и 2-й и не знает 3-й
a * 3 # знает любые 2 из 3-х, не знает любой 1 из 3-х
# Out:
# 0.35797779076563413

# %% [markdown]
# __Задача 4__
#
# Бросается игральная кость. Пусть событие `A` — появление чётного числа, событие `B` — появление числа больше трёх. Являются ли эти события независимыми?

# %%
# 1 2 3 4 5 6
# a:   [2 4 6]
# b:   [4 5 6]
# a&b: [4 6]

a = 3/6
b = 3/6
ab = 2/6
ab == a * b
# Out:
# False

# %% [markdown]
# __Задача 5__
#
# Допустим, имеется некоторая очень редкая болезнь (поражает 0.1% населения). Вы приходите к врачу, вам делают тест на эту болезнь, и тест оказывается положительным. Врач говорит вам, что этот тест верно выявляет 99% больных этой болезнью и всего лишь в 1% случаев даёт ложный положительный ответ.
#
# _Вопрос_: какова вероятность, что вы действительно больны ей?
#
# _Подсказка_: вновь используйте формулу Байеса с раскрытием знаменателя с помощью формулы полной вероятности.

# %%
# Смоделируем ситуацию: N - всего человек = 100 000
N = 100_000

bad = N * 1/1000 # Из них реально больных 0.1% = 100
ok = N - bad     # Здоровых 99 900

truepos  = bad * 99/100 # Из 100 реально больных тест определит 99
falsepos = ok * 1/100   # Из здоровых тест определит 999 как больных (1% от 99 900)
allpos   = truepos + falsepos # Всего тест определит 1098 больных из 100000 всех людей

# Ну и поделим число больных которых тест определил как истинно положительные
# на общее число положительных результатов теста
truepos/allpos

# Значение числа N на результат не влияет,
# просто подобрано чтобы получались целые числа
# в промежуточных вычислениях
# Out:
# 0.09016393442622951
